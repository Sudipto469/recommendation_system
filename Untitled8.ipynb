# %% [markdown]
# # Recommendation based on cosine similarity

# %%
import pandas as pd

# %%
use_df = pd.read_pickle("./use_df.pkl")
use_df.head(2)
# Out:
#    UserID  MovieID  Rating  Timestamp                date  hour  \
# 0       1     1193       5  978300760 2001-01-01 03:42:40     3
# 1       1      661       3  978302109 2001-01-01 04:05:09     4
#
#                                     Title  Action  Adventure  Animation  ...  \
# 0  One Flew Over the Cuckoo's Nest (1975)       0          0          0  ...
# 1        James and the Giant Peach (1996)       0          0          1  ...
#
#    Romance  Sci-Fi  Thriller  War  Western  Year  Age  Occupation  Zip-code  \
# 0        0       0         0    0        0  1975    1          10     48067
# 1        0       0         0    0        0  1996    1          10     48067
#
#    Encoded_Gender
# 0               0
# 1               0
#
# [2 rows x 30 columns]

# %%
use_df.columns
# Out:
# Index(['UserID', 'MovieID', 'Rating', 'Timestamp', 'date', 'hour', 'Title',
#        'Action', 'Adventure', 'Animation', 'Children's', 'Comedy', 'Crime',
#        'Documentary', 'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'Musical',
#        'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western', 'Year',
#        'Age', 'Occupation', 'Zip-code', 'Encoded_Gender'],
#       dtype='object')

# %% [markdown]
# <a href = https://github.com/ashwinhprasad/RecommenderSystem-CorrelationCoefficient/blob/master/CorrelationBasedRecommenderSystems.ipynb> Reference Link </a>

# %%
data_table = pd.pivot_table(use_df,values='Rating',columns='Title',index='UserID')
data_table.head()
# Out:
# Title   $1,000,000 Duck (1971)  'Night Mother (1986)  \
# UserID
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# 5                          NaN                   NaN
#
# Title   'Til There Was You (1997)  'burbs, The (1989)  \
# UserID
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# 5                             NaN                 NaN
#
# Title   ...And Justice for All (1979)  1-900 (1994)  \
# UserID
# 1                                 NaN           NaN
# 2                                 NaN           NaN
# 3                                 NaN           NaN
# 4                                 NaN           NaN
# ...

# %%
# collaborative based similarity

# %%
print("here are a list of 20 movies to recommend to a user who has liked '101 Dalmatians (1996)'")
print(data_table.corr()['101 Dalmatians (1996)'].sort_values(ascending=False).iloc[:20])
# Out:
# here are a list of 20 movies to recommend to a user who has liked '101 Dalmatians (1996)'
# Title
# Ilsa, She Wolf of the SS (1974)                                                 1.0
# Six of a Kind (1934)                                                            1.0
# Death in the Garden (Mort en ce jardin, La) (1956)                              1.0
# Beefcake (1999)                                                                 1.0
# For the Moment (1994)                                                           1.0
# Slaughterhouse (1987)                                                           1.0
# Designated Mourner, The (1997)                                                  1.0
# My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)    1.0
# Rent-a-Kid (1995)                                                               1.0
# Sugar Town (1999)                                                               1.0
# ...
